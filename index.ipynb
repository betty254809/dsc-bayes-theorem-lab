# %% [markdown]
# # Bayes' Theorem - Lab
#
# ## Introduction
#
# In this lab, you'll practice Bayes' Theorem in some simple word problems.
#
# ## Objectives
# In this lab you will be able to:
#
# - Use Bayes' theorem to determine the probability of specific events

# %% [markdown]
# ## Define a custom function for Bayes' theorem
#
# To start, write a function, `bayes()`, which takes in the probability of A, the probability of B, and the probability of B given A. From this, the function should then return the conditional probability of A, given that B is true.

# %%
def bayes(P_a, P_b, P_b_given_a):
    # Your code here
    P_not_a=1-P_a
    P_b_given_not_a=0
    P_b=(P_b_given_a+P_a)+(P_b_given_not_a*P_not_a)
    P_a_given_b=(P_b_given_a*P_a)/P_b if P_b >0 else 0
    return P_a_given_b

# %% [markdown]
# ## Skin Cancer
#
# After a physical exam, a doctor observes a blemish on a client's arm. The doctor is concerned that the blemish could be cancerous, but tells the patient to be calm and that it's probably benign. Of those with skin cancer, 100% have such blemishes. However, 20% of those without skin cancer also have such blemishes. If 15% of the population has skin cancer, what's the probability that this patient has skin cancer?
#
# > Hint: Be sure to calculate the overall rate of blemishes across the entire population.

# %%
# Your code here
def bayes_skin_cancer(p_c,p_b_given_c,p_b_given_not_c):
 p_not_c=1-p_c
 p_b=(p_b_given_c*p_c)+(p_b_given_not_c*p_not_c)
 p_c_giveb_b=(p_b_given_c_p_c)/(p_b)if p_b > 0  else 0
 p_c=0.15
 p_b_given_c=1
 p_b_given_not_c=0.02   
 result= bayes_skin_cancer(p_c,p_b_given_c,p_b_given_not_c)
 print(result)

# %% [markdown]
# ## Children
#
# A couple has two children, the older of which is a boy. What is the probability that they have two boys?

# %%
# Your solution P(2boys|older child is a boy)
def prob_two_boys():
    first_outcome=1#(B,B)
    total_outcome=2#(B,G),(B,B)
    prob=first_outcome/total_outcome
    print(prob)

# %% [markdown]
# ## A diagnostic test
#
# A diagnostic test is advertised as being 99% accurate
#
# * If a patient has the disease, they  will test positive 99% of the time
#
# * If they don't have the disease, they will test negative 99% of the time
#
# * 1% of all people have this disease
#
# If a patient tests positive, what is the probability that they actually have the disease?

# %%
# Your solution P(Disease | positive test)
def prob_diseases_given_test_positive():
   p_d=0.01#having disease
   p_t_given_d=0.99#testing positive given disease
   p_not_d=1-p_d# not having disease
   p_t_given_not_d=0.01  #testing positive given no disease
   p_t=(p_t_given_d*p_d)+(p_t_given_not_d*p_not_d)
   p_d_given_t=p_t_given_d/p_t
   print(prob_diseases_given_test_positive)

# %% [markdown]
# ## Summary
#
# In this lab, you practiced a few simple examples of Bayesian logic and how you can add prior information to update your beliefs about the chance of events.
